# %% [markdown]
# > STEP 1 — Open Google Colab & Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# STEP 2 — Load Required Packages

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# STEP 3 — Load MNIST Dataset (Training Data)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# STEP 4 — Preprocess for CNN (THIS is the key change)

# %%
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test  = x_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# STEP 5 — Build CNN Model (not Dense-only)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# STEP 7 — Train the CNN

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 65s 84ms/step - accuracy: 0.9945 - loss: 0.0178 - val_accuracy: 0.9918 - val_loss: 0.0288
# Epoch 2/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 54s 72ms/step - accuracy: 0.9959 - loss: 0.0110 - val_accuracy: 0.9926 - val_loss: 0.0271
# Epoch 3/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 49s 65ms/step - accuracy: 0.9975 - loss: 0.0085 - val_accuracy: 0.9915 - val_loss: 0.0317
# Epoch 4/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 82s 66ms/step - accuracy: 0.9978 - loss: 0.0062 - val_accuracy: 0.9912 - val_loss: 0.0353
# Epoch 5/5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 52s 69ms/step - accuracy: 0.9973 - loss: 0.0068 - val_accuracy: 0.9925 - val_loss: 0.0315

# %% [markdown]
# STEP 8 — Evaluate Model Performance

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9889 - loss: 0.0437
# Test Accuracy: 0.9914000034332275

# %% [markdown]
# STEP 9 — Save Trained CNN Model to YOUR PATH

# %%
MODEL_PATH = "/content/drive/MyDrive/cvpr/mnist_digit_cnn.h5"
model.save(MODEL_PATH)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
